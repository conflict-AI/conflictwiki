# %% [markdown]
# # ConflictWiki Data v0.1
#
# We introduce the ConflictWiki dataset, a large collection of [Wikipedia articles on armed conflict](https://en.wikipedia.org/wiki/Category:Conflicts) featuring full text on the document- and section-level. Each conflict is annotated with starting and end date, location, casualty counts, group strengths and conflict outcome. If provided on Wikipedia, entity articles feature auxiliary tabular information on languages, religion, ISO2 code and ideology.
#
#
# ## Data Directory Structure
#
# The `mappings` data directory contains four subdirectories, `conflict`, `entity`, `conflict_entity` and `network`.
#
# `conflict` contains conflict-related data and information.
# `entity` contains entity-related data and information.
# `conflict_entity` contains the conflict-entity and entity-entity relationships.
# `network` contains the conflict_entity mappings restructured as nodes and edges.
#
# If there are multiple files in a directory, they all contain the same content.
# We provide most data in multiple data formats (json, csv, pickle).
# The contents of each subdirectory is explained in the following.
#
# ```
#     |   mappings
#         |   conflict
#             |   infos / auxiliary information
#         |   entity
#             |   infos / auxiliary information
#         |   conflict_entity
#             | ally-enemy pairs
#             | conflict_entity_ids
#         |   network
#                 |   aggr_edge_list
#                 |   node_list
# ```

# %% [markdown]
# ### load external libraries

# %%
import pandas as pd
import pathlib

# %% [markdown]
# ## Conflict
#
# contains all information on the conflicts as extracted from the [Wikipedia militarized conflict template](https://en.wikipedia.org/wiki/Template:Infobox_military_conflict).
#
# `conflict_id`, `conflict_name`, `place`,  `date`, `date_start`, `date_end`, `n_belligerents`, `n_entities`, `strength`, `strength_num`, `casualties`, `casualties_num`, `commander`, `commander_num`, `result` tags.<br>
# date holds the date as a string, date_start and date_end are extracted from date and are datetime objects; <br>
# n_belligerents, n_entities state the number of entities and belligerents involved in the conflict; <br>
# strength and casualties estimate group strengths and losses per belligerent (dictionary keys are belligerent indeces); <br>
# strength_num and casualties_num are numbers extracted from strength and casualties (dictionary keys are belligerent indeces); <br>
# commander lists all military commanders per belligerent (dictionary keys are belligerent indeces); <br>
# result is a brief textual summary of the outcome  <br>

# %%
conflict_info_file = pathlib.Path().absolute().parent.absolute() / "conflict" / "conflict_info.pkl"
conflict_info = pd.DataFrame.from_dict(pd.read_pickle(conflict_info_file), orient='index')
conflict_info.index.name="conflict_id"
conflict_info
# Out:
#                                 conflict_name  \
# conflict_id
# 43063                      Operation Anaconda
# 46216            Israeli–Palestinian conflict
# 201936                  2003 invasion of Iraq
# 207031               Battle of Baghdad (2003)
# 312905                     Lebanese Civil War
# ...                                       ...
# 66384676             Battle of Konduga (2015)
# 66391098                     Battle of Damboa
# 66527448     Siege of Qamishli and Al-Hasakah
# 66530305                          Orlu Crisis
# 66567997             2021 Myanmar coup d'état
#
#                                                            url  \
# conflict_id
# 43063         https://en.wikipedia.org/wiki/Operation_Anaconda
# 46216        https://en.wikipedia.org/wiki/Israeli–Palestin...
# 201936       https://en.wikipedia.org/wiki/2003_invasion_of...
# 207031       https://en.wikipedia.org/wiki/Battle_of_Baghda...
# 312905        https://en.wikipedia.org/wiki/Lebanese_Civil_War
# ...                                                        ...
# 66384676     https://en.wikipedia.org/wiki/Battle_of_Kondug...
# 66391098        https://en.wikipedia.org/wiki/Battle_of_Damboa
# 66527448     https://en.wikipedia.org/wiki/Siege_of_Qamishl...
# 66530305             https://en.wikipedia.org/wiki/Orlu_Crisis
# 66567997     https://en.wikipedia.org/wiki/2021_Myanmar_cou...
#
#              n_belligerents  n_entities  \
# conflict_id
# 43063                     2          16
# 46216                     2           7
# 201936                    2          17
# 207031                    2           3
# 312905                    4          28
# ...                     ...         ...
# 66384676                  2           2
# 66391098                  2           2
# 66527448                  2           2
# 66530305                  2           3
# 66567997                  2           3
#
#                                                          place  \
# conflict_id
# 43063        Shahi Kot Valley, Paktia Province, Islamic Sta...
# 46216        Middle EastPrimarily in Israel, West Bank, Gaz...
# 201936                                                    Iraq
# 207031                                 Baghdad, Ba'athist Iraq
# 312905                                                 Lebanon
# ...                                                        ...
# 66384676                                      Konduga, Nigeria
# 66391098                                       Damboa, Nigeria
# 66527448                        Qamishli and Al-Hasakah, Syria
# 66530305                   Orlu, Imo; Orlu, Imo State, Nigeria
# 66567997                                               Myanmar
#
#                                                           date  date_start  \
# conflict_id
# 43063                                         March 1-18, 2002  2022-03-01
# 46216          Mid-20th century - presentMain phase: 1964-1993  2021-04-13
# 201936                                  20 March - 1 May 2003   2022-03-20
# 207031                                        3-12 April 2003   2021-04-13
# 312905       13 April 1975 - 13 October 1990 Battle of Sido...  1975-04-13
# ...                                                        ...         ...
# 66384676                                          2 March 2015  2015-03-02
# 66391098                                        October 6 2013  2013-10-06
# 66527448                           10 January - 2 February 202  2022-01-10
# 66530305                                    22-28 January 2021  2021-04-13
# 66567997                                       1 February 2021  2021-02-01
#
#                date_end                                             status  \
# conflict_id
# 43063        2021-04-13
# 46216        2021-04-13  Israeli–Palestinian peace proceslow-level figh...
# 201936       2003-05-01                                               None
# 207031       2003-04-12                                               None
# 312905       1990-10-13                                               None
# ...                 ...                                                ...
# 66384676           None                                               None
# 66391098           None                                               None
# 66527448     2022-02-02                                               None
# 66530305     2021-01-28
# 66567997           None                                               None
#
#                                                     casualties  \
# conflict_id
# 43063        {0: '7 Afghan fighters killed  8 (7 in the Bat...
# 46216        {0: '', 1: '', 2: '21,500 casualties (1965–201...
# 201936       {0: 'Coalition: 214 killed606 wounded (U.S.)Pe...
# 207031       {0: '1,700–2,120 killed (independent estimate)...
# 312905                                                      {}
# ...                                                        ...
# 66384676                  {0: '73 insurgents', 1: '1 soldier'}
# 66391098     {0: '15 killed', 1: 'none', 2: '7 civilians ki...
# 66527448     {0: 'None', 1: '1 killedhttps://www.syriahr.co...
# 66530305     {0: '4+ killed ', 1: 'Unknown', 2: '10+ civili...
# 66567997                    {0: '', 1: '', 2: 'None reported'}
#
#                                                 casualties_num  \
# conflict_id
# 43063        {0: [7.0, 8.0, 7.0, 2015.0, 66.0], 1: [500.0, ...
# 46216        {2: [21500.0, 1965.0, 2013.0, 1946.0, 2012.0, ...
# 201936       {0: [214.0, 606.0, 24.0, 238.0, 1000.0], 1: [3...
# 207031       {0: [1700.0, 2120.0, 2320.0], 1: [34.0, 1.0, 2...
# 312905                                                      {}
# ...                                                        ...
# 66384676                                 {0: [73.0], 1: [1.0]}
# 66391098                                 {0: [15.0], 2: [7.0]}
# 66527448     {1: [1.0, 203176.0, 7.0, 203176.0, 3.0], 2: [6...
# 66530305     {0: [4.0], 2: [10.0, 28.0, 2021.0, 28.0, 2021.0]}
# 66567997                                                    {}
#
#                                    casualties_sum  \
# conflict_id
# 43063                      {0: 2103.0, 1: 3382.0}
# 46216                                {2: 35439.0}
# 201936       {0: 2082.0, 1: 172996.0, 2: 14769.0}
# 207031                       {0: 6140.0, 1: 54.0}
# 312905                                         {}
# ...                                           ...
# 66384676                        {0: 73.0, 1: 1.0}
# 66391098                        {0: 15.0, 2: 7.0}
# 66527448               {1: 406363.0, 2: 203182.0}
# 66530305                      {0: 4.0, 2: 4108.0}
# 66567997                                       {}
#
#                                                       strength  \
# conflict_id
# 43063                                {0: '30,000', 1: '1,000'}
# 46216                                           {0: '', 1: ''}
# 201936       {0: ': 192,000 personnel: 45,000 troops : 2,00...
# 207031                              {0: '45,000', 1: '30,000'}
# 312905       {0: '', 1: '', 2: ' 25,000 troops (1976)', 3: ...
# ...                                                        ...
# 66384676     {0: '~150 insurgents', 1: 'Unknown number of s...
# 66391098                          {0: 'Unknown', 1: 'Unknown'}
# 66527448                                 {0: '', 1: '', 2: ''}
# 66530305     {0: 'More than 400 soldiersTension heightens i...
# 66567997                                                    {}
#
#                                                   strength_num  \
# conflict_id
# 43063                              {0: [30000.0], 1: [1000.0]}
# 46216                                                       {}
# 201936       {0: [192000.0, 45000.0, 2000.0, 194.0, 70000.0...
# 207031                            {0: [45000.0], 1: [30000.0]}
# 312905       {2: [25000.0, 1976.0], 3: [1200.0, 1000.0, 100...
# ...                                                        ...
# 66384676                                {0: [150.0], 1: [1.0]}
# 66391098                                                    {}
# 66527448                                                    {}
# 66530305       {0: [400.0, 400.0, 28.0, 2021.0, 28.0, 2021.0]}
# 66567997                                                    {}
#
#                             strength_sum  \
# conflict_id
# 43063            {0: 30000.0, 1: 1000.0}
# 46216                                 {}
# 201936       {0: 619628.0, 1: 4015761.0}
# 207031          {0: 45000.0, 1: 30000.0}
# 312905           {2: 26976.0, 3: 4600.0}
# ...                                  ...
# 66384676              {0: 150.0, 1: 1.0}
# 66391098                              {}
# 66527448                              {}
# 66530305                     {0: 4898.0}
# 66567997                              {}
#
#                                                      commander  \
# conflict_id
# 43063        {0: ['United States', 'Rowan Tink', 'Australia...
# 46216                                           {0: [], 1: []}
# 201936       {0: ['Aleksander Kwa', 'Poland', 'George W. Bu...
# 207031       {0: ['Ra'ad al-Hamdani', 'Sayf al-Din al-Rawi'...
# 312905       {0: ['Death by natural causes', 'Etienne Saqr'...
# ...                                                        ...
# 66384676                                                    {}
# 66391098                                                    {}
# 66527448                                                    {}
# 66530305     {0: ['Muhammadu Buhari', 'President of Nigeria...
# 66567997     {0: ['Win Myint', 'Aung San Suu Kyi', 'Preside...
#
#                                                         result
# conflict_id
# 43063        Coalition victory, Taliban evacuates but suffe...
# 46216                                                     None
# 201936       Coalition operational success  Ba'athist Iraq ...
# 207031       Decisive Coalition victory  Fall of Ba'ath Par...
# 312905       Taif Agreement Christian 55:45 ascendancy repl...
# ...                                                        ...
# 66384676                                      Nigerian victory
# 66391098                                      Nigerian victory
# 66527448                                          Siege lifted
# 66530305                          Both sides withdraw from Orl
# 66567997     Military coup d'état successful  End of civili...
#
# [1145 rows x 17 columns]

# %% [markdown]
# ## Entity
#
# contains all information on the entities as extracted from the [Wikipedia article info box](https://en.wikipedia.org/wiki/Mali).
#
# `entity_id`, `entity_name`, `num_conflicts`, `iso`, `language`, `religion`, `ideology` <br>
# num_conflicts gives the number of conflicts, the entity is involved in; <br>

# %%
entity_info_file = pathlib.Path().absolute().parent.absolute() / "entity" / "entity_info.pkl"
entity_info = pd.DataFrame.from_dict(pd.read_pickle(entity_info_file), orient='index')
entity_info.index.name="entity_id"
entity_info
# Out:
#                                 entity_name  \
# entity_id
# 4689264                           Australia
# 3434750                       United States
# 5042916                              Canada
# 76972                               Denmark
# 11867                               Germany
# ...                                     ...
# 38762388   Sahrawi Arab Democratic Republic
# 4853315                        Gumuz people
# 6223534              Oromo Liberation Front
# 20390                   Politics of Myanmar
# 20394                              Tatmadaw
#
#                                                          url  num_conflicts  \
# entity_id
# 4689264              https://en.wikipedia.org/wiki/Australia             32
# 3434750          https://en.wikipedia.org/wiki/United_States            301
# 5042916                 https://en.wikipedia.org/wiki/Canada             42
# 76972                  https://en.wikipedia.org/wiki/Denmark             24
# 11867                  https://en.wikipedia.org/wiki/Germany             20
# ...                                                      ...            ...
# 38762388   https://en.wikipedia.org/wiki/Sahrawi_Arab_Dem...              2
# 4853315           https://en.wikipedia.org/wiki/Gumuz_people              1
# 6223534    https://en.wikipedia.org/wiki/Oromo_Liberation...              1
# 20390      https://en.wikipedia.org/wiki/Politics_of_Myanmar              1
# 20394                 https://en.wikipedia.org/wiki/Tatmadaw              1
#
#           iso                                           language  \
# entity_id
# 4689264    AU  [National language, English, Australian Englis...
# 3434750    US  [Spanish, Algonquian languages, Cherokee langu...
# 5042916    CA  [English, Canadian French, Canadian English, F...
# 76972      DK                          [Danish, Danish language]
# 11867      EU  [European Charter for Regional or Minority Lan...
# ...        ..                                                ...
# 38762388   <!  [Spanish, Arabic, Spanish language, Modern Sta...
# 4853315    []                                                 []
# 6223534    []                                                 []
# 20390      []                                                 []
# 20394      []                                                 []
#
#                                                     ideology  \
# entity_id
# 4689264                                                   []
# 3434750                                                   []
# 5042916                                                   []
# 76972                                                     []
# 11867                                                     []
# ...                                                      ...
# 38762388                                                  []
# 4853315                                                   []
# 6223534    [Ethnic nationalism, Secularism, Oromo nationa...
# 20390                                                     []
# 20394                                                     []
#
#                                                     religion
# entity_id
# 4689264                                                   []
# 3434750                      [Religion in the United States]
# 5042916                                                   []
# 76972      [Church of the Faroe Islands, Greenland, No re...
# 11867                                                     []
# ...                                                      ...
# 38762388                                             [Islam]
# 4853315                                                   []
# 6223534                                                   []
# 20390                                                     []
# 20394                                                     []
#
# [1245 rows x 7 columns]

# %% [markdown]
# ## Conflict_Entity
#
# ##### conflict_entity_id
#
# Contains the ids of all conflicts and the ids of all involved entities partitioned into belligerents.
# In the examplatory conflict below, we have three belligerents, of which the first two are formed by two entities each
# and the third belligerent consists of only one entity
#
# ```
# {conflict_id: [[entity_id, entity_id, entity_id, entity_id],[entity_id]]}
# (1220919: [[1576797, 31717, 4887, 3434750], [40596311]])
# ```

# %%
conflict_entity_id_file = pathlib.Path().absolute().parent.absolute() / "mappings" / "conflict_entity" / "conflict_entity_id.pkl"
#conflict_entity_id = pd.read_pickle(conflict_entity_id_file)
conflict_entity_id= pd.DataFrame.from_dict(pd.read_pickle(conflict_entity_id_file), orient='index', columns = ["belligerent_1", "belligerent_2", "belligerent_3", "belligerent_4"])
conflict_entity_id.index.name="conflict_id"
conflict_entity_id
# Out:
#                                                  belligerent_1  \
# conflict_id
# 22738        [27019, 1737554, 17207794, 4913064, 23235, 318...
# 43063        [21241, 291717, 4913064, 31717, 11125639, 737,...
# 46216                                                [9282173]
# 106346               [1113713, 23235, 3607937, 31769, 3434750]
# 201936       [899044, 22936, 31717, 679693, 7515928, 256597...
# ...                                                        ...
# 64786838                                              [469639]
# 65268074                 [12593188, 171166, 5217236, 14833748]
# 65431221                       [11125639, 73374, 746, 8862873]
# 65548110                                            [11125639]
# 66219979                                    [7515928, 3434750]
#
#                                                  belligerent_2 belligerent_3  \
# conflict_id
# 22738        [103100, 51673, 737, 30635, 27358, 21462079, 3...          None
# 43063                                   [389363, 737, 4512092]          None
# 46216         [24093, 12047, 24324, 13913, 53185055, 13093253]          None
# 106346                                               [8089426]          None
# 201936        [7515849, 26215470, 285632, 2185, 199866, 17633]          None
# ...                                                        ...           ...
# 64786838                                    [43667081, 298010]          None
# 65268074                                               [66890]          None
# 65431221          [214413, 3057255, 25391, 44596915, 10918072]          None
# 65548110                                               [69680]          None
# 66219979                                  [39955935, 40596311]          None
#
#             belligerent_4
# conflict_id
# 22738                None
# 43063                None
# 46216                None
# 106346               None
# 201936               None
# ...                   ...
# 64786838             None
# 65268074             None
# 65431221             None
# 65548110             None
# 66219979             None
#
# [383 rows x 4 columns]

# %% [markdown]
# ##### ally_enemy_pairs
#
# Contains the ids of entity pairs, a conflict id and the relationship of the entities in the given conflict as displayed below
#
# ```
# ((entity_pair), conflict_id, entity_relationship)
# ((27019, 103100), 22738, "enemies")

# %%
ally_enemy_pairs_file = pathlib.Path().absolute().parent.absolute() / "mappings" / "conflict_entity" / "ally_enemy_pairs.pkl"
#ally_enemy_pairs = pd.read_pickle(ally_enemy_pairs_file)
ally_enemy_pairs= pd.DataFrame(pd.read_pickle(ally_enemy_pairs_file),columns = ["entity_pair", "conflict_id", "entity_relationship"])
ally_enemy_pairs.index.name="entity_pair_id"
ally_enemy_pairs
# Out:
#                          entity_pair  conflict_id entity_relationship
# entity_pair_id
# 0                    (27019, 103100)        22738             enemies
# 1                     (27019, 51673)        22738             enemies
# 2                       (27019, 737)        22738             enemies
# 3                     (27019, 30635)        22738             enemies
# 4                     (27019, 27358)        22738             enemies
# ...                              ...          ...                 ...
# 17066              (25391, 44596915)     66219979             enemies
# 17067              (25391, 10918072)     66219979             enemies
# 17068           (44596915, 10918072)     66219979             enemies
# 17069             (7515928, 3434750)     66219979              allies
# 17070           (39955935, 40596311)     66219979              allies
#
# [17071 rows x 3 columns]

# %% [markdown]
# ## Network
#
# Contains the precomputed, aggregated network, where nodes are entities and edges are all conflicts between any two respective entities aggregated.
#
# ###### aggr_edge_list
#
# List of edges of shape (node_id 1, node_id 2, edge attributes)
#
# ```
# (entity_id 1, entity_id 2, conflict attributes
# 27019,	103100,	{'label': 'enemies', 'label_discrete': 0, 'label_continuous': -1, 'n_conflicts': 1, 'conflict_ids': [22738], 'conflict_names': ['Operation Enduring Freedom']}
# ```

# %%
aggr_edge_list_file = pathlib.Path().absolute().parent.absolute() / "mappings" / "network" / "aggr_edge_list.pkl"
aggr_edge_list = pd.DataFrame(pd.read_pickle(aggr_edge_list_file),columns = ["entity_id_1", "entity_id_1", "conflict_attributes"])
aggr_edge_list.index.name="edge"
aggr_edge_list
# Out:
#        entity_id_1  entity_id_1  \
# edge
# 0            27019       103100
# 1            27019        51673
# 2              737        27019
# 3            27019        30635
# 4            27019        27358
# ...            ...          ...
# 10832       214413     44596915
# 10833       214413     10918072
# 10834        25391      3057255
# 10835      3057255     44596915
# 10836      3057255     10918072
#
#                                      conflict_attributes
# edge
# 0      {'label': 'enemies', 'label_discrete': 0, 'lab...
# 1      {'label': 'enemies', 'label_discrete': 0, 'lab...
# 2      {'label': 'enemies', 'label_discrete': 0, 'lab...
# 3      {'label': 'enemies', 'label_discrete': 0, 'lab...
# 4      {'label': 'allies', 'label_discrete': 1, 'labe...
# ...                                                  ...
# 10832  {'label': 'allies', 'label_discrete': 1, 'labe...
# 10833  {'label': 'allies', 'label_discrete': 1, 'labe...
# 10834  {'label': 'allies', 'label_discrete': 1, 'labe...
# 10835  {'label': 'enemies', 'label_discrete': 0, 'lab...
# 10836  {'label': 'enemies', 'label_discrete': 0, 'lab...
#
# [10837 rows x 3 columns]

# %% [markdown]
# ###### node_list
#
# List of nodes (node_id, node attributes)
#
# ```
# (entity_id, entity attributes
# 3343, {'name': 'Belgium'}
# ```

# %%
node_list_file = pathlib.Path().absolute().parent.absolute() / "mappings" / "network" / "node_list.pkl"
node_list= pd.DataFrame(pd.read_pickle(node_list_file),columns = ["entity_id", "entity_attributes"])
node_list.index.name="node"
node_list
# Out:
#       entity_id                                  entity_attributes
# node
# 0           358                                {'name': 'Algeria'}
# 1           701                                 {'name': 'Angola'}
# 2           737                            {'name': 'Afghanistan'}
# 3           738                                {'name': 'Albania'}
# 4           746                             {'name': 'Azerbaijan'}
# ...         ...                                                ...
# 711    38264234  {'name': 'European Union Training Mission in M...
# 712    40479968  {'name': 'United Nations Force Intervention Br...
# 713    43112164  {'name': 'European Union Training Mission in S...
# 714    45690137      {'name': 'Grupos de autodefensa comunitaria'}
# 715    53185055             {'name': 'All-Palestine Protectorate'}
#
# [716 rows x 2 columns]
