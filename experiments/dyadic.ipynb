# %% [markdown]
# # Dyadic Setting

# %% [markdown]
# ### import libraries

# %%
from wb0configs import configs
from wb4task.setting_transductive.trans_batched_dataload_class import load_data
from wb4task.setting_transductive.trans_batched_train_class import Trainer
from wb4task.setting_dyadic.no_gnn import Model, Model_Trainer

# %% [markdown]
# ### data loading

# %%
config = configs.ConfigBase()
dl, val_test_dl, graph, label_info, wikinetworkdata = load_data(config, batch_size = 512, n_val= 0.3, n_test= 0.1, neighborhood_steps= 1, random_node_frac = 0.0, random_label_frac = 1.0)
# Out:
# target labels: [0 1] [18916 17416]
# batch size: 512 train edges: 21799 , val edges: 10899 , test edges: 3634

# %% [markdown]
# ### training

# %%
model = Model(node_feature_dim = 500, node_reducer_out = 64, include_edge_features = True)

trainer = Model_Trainer(wikinetworkdata, label_info)
model = trainer.train_model(dl, model, graph, n_epochs=30, early_stop=4, lr = 0.001, weight_decay=1e-5)
trainer.evaluate_model(model, val_test_dl)
# Out:
# epoch: 1/30, train loss: 0.679, train acc: 0.516, val Loss: 0.681, val acc: 0.513
# epoch: 2/30, train loss: 0.544, train acc: 0.707, val Loss: 0.554, val acc: 0.702
# epoch: 3/30, train loss: 0.449, train acc: 0.767, val Loss: 0.475, val acc: 0.75
# epoch: 4/30, train loss: 0.382, train acc: 0.799, val Loss: 0.422, val acc: 0.786
# epoch: 5/30, train loss: 0.34, train acc: 0.828, val Loss: 0.397, val acc: 0.806
# epoch: 6/30, train loss: 0.319, train acc: 0.84, val Loss: 0.386, val acc: 0.817
# epoch: 7/30, train loss: 0.303, train acc: 0.845, val Loss: 0.377, val acc: 0.826
# epoch: 8/30, train loss: 0.29, train acc: 0.851, val Loss: 0.382, val acc: 0.833
# epoch: 9/30, train loss: 0.276, train acc: 0.858, val Loss: 0.365, val acc: 0.836
# epoch: 10/30, train loss: 0.27, train acc: 0.859, val Loss: 0.362, val acc: 0.84
# epoch: 11/30, train loss: 0.264, train acc: 0.863, val Loss: 0.362, val acc: 0.841
# epoch: 12/30, train loss: 0.276, train acc: 0.86, val Loss: 0.382, val acc: 0.837
# epoch: 13/30, train loss: 0.264, train acc: 0.861, val Loss: 0.354, val acc: 0.841
# epoch: 14/30, train loss: 0.251, train acc: 0.869, val Loss: 0.353, val acc: 0.846
# epoch: 15/30, train loss: 0.256, train acc: 0.869, val Loss: 0.358, val acc: 0.848
# epoch: 16/30, train loss: 0.25, train acc: 0.869, val Loss: 0.354, val acc: 0.85
# epoch: 17/30, train loss: 0.245, train acc: 0.87, val Loss: 0.355, val acc: 0.849
# early stopping
# optimal_threshold: 0.6530913
#
# roc_auc: 0.9563075039833085 prec: 0.8781362007168458 rec: 0.8760429082240763 f1: 0.8770883054892601 support: None
